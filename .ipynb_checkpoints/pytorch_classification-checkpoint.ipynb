# %%
import os

# %%
video_dir = '../WLASL/start_kit/videos'

# %%
labels = os.listdir(video_dir)

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# anyio                         3.6.2
# appnope                       0.1.3
# argon2-cffi                   21.1.0
# asttokens                     2.2.1
# attrs                         22.2.0
# Babel                         2.12.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.12.2
# bleach                        6.0.0
# brotlipy                      0.7.0
# certifi                       2022.12.7
# cffi                          1.15.1
# charset-normalizer            3.1.0
# colorama                      0.4.6
# cryptography                  39.0.1
# decorator                     5.1.1
# defusedxml                    0.7.1
# entrypoints                   0.4
# executing                     1.2.0
# fastjsonschema                2.16.3
# fsspec                        2023.4.0
# future                        0.18.3
# idna                          3.4
# importlib-metadata            6.6.0
# importlib-resources           5.12.0
# ipykernel                     5.5.5
# ipython                       8.12.0
# ipython-genutils              0.2.0
# jedi                          0.18.2
# Jinja2                        3.1.2
# json5                         0.9.5
# jsonschema                    4.17.3
# jupyter-client                7.3.4
# jupyter_core                  5.3.0
# jupyter-server                1.23.6
# jupyterlab                    3.5.3
# jupyterlab-pygments           0.2.2
# jupyterlab_server             2.22.1
# lightning-utilities           0.8.0
# MarkupSafe                    2.1.1
# matplotlib-inline             0.1.6
# mistune                       2.0.5
# nbclassic                     0.5.6
# nbclient                      0.7.4
# nbconvert                     7.3.1
# nbformat                      5.8.0
# nest-asyncio                  1.5.6
# notebook                      6.5.4
# notebook_shim                 0.2.3
# numpy                         1.24.3
# packaging                     23.1
# pandocfilters                 1.5.0
# parso                         0.8.3
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.4.0
# pip                           23.0.1
# pkgutil_resolve_name          1.3.10
# platformdirs                  3.5.0
# prometheus-client             0.16.0
# prompt-toolkit                3.0.38
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# pycparser                     2.21
# Pygments                      2.15.1
# pyOpenSSL                     23.1.1
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# python-dateutil               2.8.2
# pytorch-lightning             2.0.2
# pytz                          2023.3
# PyYAML                        6.0
# pyzmq                         25.0.2
# requests                      2.29.0
# Send2Trash                    1.8.0
# setuptools                    66.0.0
# six                           1.16.0
# sniffio                       1.3.0
# soupsieve                     2.3.2.post1
# stack-data                    0.6.2
# terminado                     0.17.1
# tinycss2                      1.2.1
# tomli                         2.0.1
# torch                         1.12.1
# torchaudio                    0.12.1
# torchmetrics                  0.11.4
# torchvision                   0.13.1
# tornado                       6.1
# tqdm                          4.65.0
# traitlets                     5.9.0
# typing_extensions             4.5.0
# urllib3                       1.26.15
# wcwidth                       0.2.6
# webencodings                  0.5.1
# websocket-client              1.5.1
# wheel                         0.38.4
# zipp                          3.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

class VideoDataset(Dataset):
    def __init__(self, data_dir, split="train", test_size=0.1, val_size=0.1, random_state=429):
        self.labels = os.listdir(data_dir)
        self.label_to_idx = {label: idx for idx, label in enumerate(self.labels)}
        self.data = []
        for label in self.labels:
            label_dir = os.path.join(data_dir, label)
            video_files = os.listdir(label_dir)
            for video_file in video_files:
                video_path = os.path.join(label_dir, video_file)
                self.data.append((video_path, label))
                
        train_val_data, test_data = train_test_split(self.data, test_size=test_size, random_state=random_state)

        if split == "train":
            train_data, val_data = train_test_split(train_val_data, test_size=val_size/(1-test_size), random_state=random_state)
            self.data = train_data
        elif split == "val":
            train_data, val_data = train_test_split(train_val_data, test_size=val_size/(1-test_size), random_state=random_state)
            self.data = val_data
        elif split == "test":
            self.data = test_data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        video_path, label = self.data[idx]
        video = cv2.VideoCapture(video_path)
        frames = []
        while True:
            ret, frame = video.read()
            if not ret:
                break
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame = cv2.resize(frame, (224, 224))
            frame = transforms.ToTensor()(frame)
            frames.append(frame)
        video_tensor = torch.stack(frames, dim=0)
        label_idx = self.label_to_idx[label]
        return video_tensor, label_idx

# %%
train_data = VideoDataset(video_dir, split="train")
train_loader = DataLoader(train_data, batch_size=4, shuffle=True)

val_data = VideoDataset(video_dir, split="val")
val_loader = DataLoader(val_data, batch_size=4, shuffle=True)

test_data = VideoDataset(video_dir, split="test")
test_loader = DataLoader(test_data, batch_size=4, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[22], line 7
#       4 val_data = VideoDataset(video_dir, split="val")
#       5 val_loader = DataLoader(val_data, batch_size=4, shuffle=True)
# ----> 7 test_data = VideoDataset(video_dir, split="test")
#       8 test_loader = DataLoader(test_data, batch_size=4, shuffle=True)
#
# Cell In[21], line 31, in VideoDataset.__init__(self, data_dir, split, test_size, val_size, random_state)
#      29     self.data = val_data
#      30 elif split == "test":
# ---> 31     self.data = test_data
#
# UnboundLocalError: local variable 'test_data' referenced before assignment

# %%
val_data.data
# Out:
# [('../WLASL/start_kit/videos/book/07088.mp4', 'book'),
#  ('../WLASL/start_kit/videos/book/07075.mp4', 'book'),
#  ('../WLASL/start_kit/videos/book/07074.mp4', 'book'),
#  ('../WLASL/start_kit/videos/before/05732.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05733.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05727.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05731.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05724.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05730.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05734.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05750.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05744.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05746.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05747.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05743.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05742.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05740.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05741.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/68007.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05749.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05748.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05739.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05729.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/05728.mp4', 'before'),
#  ('../WLASL/start_kit/videos/before/70348.mp4', 'before'),
#  ('../WLASL/start_kit/videos/computer/12312.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12306.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12313.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12311.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12338.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12328.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12314.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12315.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12329.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12317.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12316.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/68028.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12333.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12327.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12326.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12330.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12318.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12319.mp4', 'computer'),
#  ('../WLASL/start_kit/videos/computer/12331.mp4', 'computer')]
